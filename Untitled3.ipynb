# %% [markdown]
# Overall crime rate of Chicago,eespecially homocides, is substantially higher than the US average.
# This analysis exlpores the crime rate from year 2012 to year 2017and compare the number of arrests with the number of crimes.

# %%
import pandas as pd
from pandas import read_csv
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.offline as py
import seaborn as sns

# %%
crimes = read_csv('Chicago_Crimes_2012_to_2017.csv', index_col='Date')
# Out:
# /Users/ioannakalogianni/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
crimes.head()
# Out:
#                         Unnamed: 0        ID Case Number                Block  \
# Date
# 05/03/2016 11:40:00 PM           3  10508693    HZ250496   013XX S SAWYER AVE
# 05/03/2016 09:40:00 PM          89  10508695    HZ250409   061XX S DREXEL AVE
# 05/03/2016 11:31:00 PM         197  10508697    HZ250503  053XX W CHICAGO AVE
# 05/03/2016 10:10:00 PM         673  10508698    HZ250424    049XX W FULTON ST
# 05/03/2016 10:00:00 PM         911  10508699    HZ250455    003XX N LOTUS AVE
#
#                         IUCR            Primary Type              Description  \
# Date
# 05/03/2016 11:40:00 PM  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 05/03/2016 09:40:00 PM  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 05/03/2016 11:31:00 PM  0470  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 05/03/2016 10:10:00 PM  0460                 BATTERY                   SIMPLE
# 05/03/2016 10:00:00 PM  0820                   THEFT           $500 AND UNDER
#
# ...

# %%
crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1165248 entries, 05/03/2016 11:40:00 PM to 11/16/2015 08:00:00 PM
# Data columns (total 22 columns):
# Unnamed: 0              1165248 non-null int64
# ID                      1165248 non-null int64
# Case Number             1165248 non-null object
# Block                   1165248 non-null object
# IUCR                    1165247 non-null object
# Primary Type            1165247 non-null object
# Description             1165247 non-null object
# Location Description    1164543 non-null object
# Arrest                  1165247 non-null object
# Domestic                1165247 non-null object
# Beat                    1165247 non-null float64
# District                1165246 non-null float64
# Ward                    1165233 non-null float64
# Community Area          1165207 non-null float64
# FBI Code                1165247 non-null object
# X Coordinate            1155862 non-null float64
# ...

# %%
crimes.index = pd.to_datetime(crimes.index)

# %%
crimes.head()
# Out:
#                      Unnamed: 0        ID Case Number                Block  \
# Date
# 2016-05-03 23:40:00           3  10508693    HZ250496   013XX S SAWYER AVE
# 2016-05-03 21:40:00          89  10508695    HZ250409   061XX S DREXEL AVE
# 2016-05-03 23:31:00         197  10508697    HZ250503  053XX W CHICAGO AVE
# 2016-05-03 22:10:00         673  10508698    HZ250424    049XX W FULTON ST
# 2016-05-03 22:00:00         911  10508699    HZ250455    003XX N LOTUS AVE
#
#                      IUCR            Primary Type              Description  \
# Date
# 2016-05-03 23:40:00  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 2016-05-03 21:40:00  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 2016-05-03 23:31:00  0470  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 2016-05-03 22:10:00  0460                 BATTERY                   SIMPLE
# 2016-05-03 22:00:00  0820                   THEFT           $500 AND UNDER
#
# ...

# %% [markdown]
# Explore number of crimes throughout the years 2012 to 2016.As we can see the highest number of murders takes place between 2012 and 2013 and the lowest is in 2016, even though the media claimed that 2016 was the year with the highest crime rate in the city of Chicago.

# %%
plt.figure(figsize=(20,10))

crimes.resample('M').size().plot(legend=False)
plt.title('Number of crimes per year (2012 - 2016)')
plt.xlabel('Years')
plt.ylabel('Number of crimes')
plt.show()

# %% [markdown]
# The graph below demonstrates the Types of crime.

# %%
plt.figure(figsize=(20,10))

crimes.groupby([crimes['Primary Type']]).size().sort_values(ascending=True).plot(kind='barh')
plt.title('Number of crimes by type')
plt.ylabel('Crime Type')
plt.xlabel('Number of crimes')
plt.show()

# %%
The graph below demonstates the most usual places where a crime takes place.

# %%
plt.figure(figsize=(20,30))

crimes.groupby([crimes['Location Description']]).size().sort_values(ascending=True).plot(kind='barh')
plt.title('Number of crimes by Location')
plt.ylabel('Crime Location')
plt.xlabel('Number of crimes')
plt.show()

# %%
crimes.index = pd.to_datetime(crimes.index)

# %%
domestic_yearly = crimes[crimes['Domestic'] == True]['Domestic']
print(domestic_yearly.head())
# Out:
# Date
# 2016-05-03 23:40:00    True
# 2016-05-03 21:40:00    True
# 2016-05-03 22:00:00    True
# 2016-05-03 22:30:00    True
# 2016-05-03 23:11:00    True
# Name: Domestic, dtype: object

# %% [markdown]
# The most exceptional is the rate of domestic violence which is extremely lower in 2016 than than the previous years.

# %%
domestic_yearly.resample('A').sum().plot()
plt.title('Yearly domestic violence')
plt.show()

# %%
The overall number of crimes per year.

# %%
by_year=crimes.groupby("Year").size().to_frame().reset_index().rename(columns={0:"Count"}).sort_values("Count",ascending=False)
by_year.head()
# Out:
#      Year   Count
# 0  2012.0  334814
# 1  2013.0  305917
# 2  2014.0  273280
# 3  2015.0  223156
# 4  2016.0   28080

# %%
crimes1 = pd.DataFrame(crimes[crimes['Primary Type'].isin(['THEFT','BATTERY', 'CRIMINAL DAMAGE', 'NARCOTICS', 'ASSAULT', 'PROSTITUTION'])]['Primary Type'])

# %%
crimes2 = crimes1.groupby([pd.TimeGrouper('M'), 'Primary Type'])

# %%
data = crimes2['Primary Type'].count().unstack()

# %%
data.plot()
plt.title("Top 5 monthly crimes")
plt.show()
